# %% [markdown]
# # Big O Notation

# %% [markdown]
# <img>![image.png](attachment:image.png)

# %% [markdown]
# ## Rules
#
# ### 1. Worst Case
# We only care about the worst case scenario... Think of a for-loop with a condition. If we try and find an item in the list, whether we find it on the first iteration or the last, we always will measure using the worst scenario.
# ### 2. Remove Constants
# ### 3. Different terms for inputs
# ### 4. Drop Non-Dominants
# Again, this goes back to the worst case (or at least that is how I process it. We want to get the term that (when scaled) produces the worst scenario. Looking above at our chart, O(n^2) would be used over O(n log n).

# %% [markdown]
# ## Big O Notation Cheat Sheet
#
# - O(1) Constant- no loops
# - O(log N) Logarithmic- usually searching algorithms have log n if they are sorted (Binary Search)
# - O(n) Linear- for loops, while loops through n items
# - O(n log(n)) Log Liniear- usually sorting operations
# - O(n^2) Quadratic- every element in a collection needs to be compared to ever other element. Two
# nested loops
# - O(2^n) Exponential- recursive algorithms that solves a problem of size N
# - O(n!) Factorial- you are adding a loop for every element

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3 Pillars of Programming
# 1. Readability
# 2. Speed (Time Complexity)
# 3. Memory (Space Complexity)

# %% [markdown]
# ### Space Complexity (Memory)

# %% [markdown]
# 1. Heap
# 2. Stack

# %% [markdown]
# #### What Causes Space Complexity?
# 1.
